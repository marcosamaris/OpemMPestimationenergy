# %% [markdown]
# # INICIO

# %%
import pandas as pd
import numpy as np
import seaborn as srn
import statistics as sts
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
caminhos_csv = ['/content/drive/MyDrive/TCC/DADOS/STREAM.csv',
                '/content/drive/MyDrive/TCC/DADOS/MYO.csv',
                '/content/drive/MyDrive/TCC/DADOS/LUD.csv',
                '/content/drive/MyDrive/TCC/DADOS/LAVAMD.csv',
                '/content/drive/MyDrive/TCC/DADOS/BACKPROP.csv']

nomes_benchmarks = ['Stream Cluster', 'Myocyte', 'LU Decomposition', 'Lava MD', 'Back Propagation']

# %%
def microjoule_to_joule(value):
  valor = 1000000
  colunas= ['CORE','CPU','DRAM','DURATION','UNCORE']
  value[colunas] = value[colunas]/valor
  value[colunas] = round(value[colunas], 2)
  return value

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #1 Parte - SubPlot de cada benchmark comparado consumos com Inputs

# %% [markdown]
# ## 1.1- Lava MD

# %%
dados = pd.read_csv('/content/drive/MyDrive/TCC/DADOS/LAVAMD.csv', sep=';')

dados = dados.drop(columns=["EXIT_CODE"])

dados = microjoule_to_joule(dados)

dados['ENERGY'] = dados['CPU'] + dados['DRAM'] + dados['UNCORE']

df = dados.groupby('INPUT').mean()
# Criando a figura e os subplots
fig, axs = plt.subplots(2, 3, figsize=(16, 8))
fig.suptitle('Lava MD')

# Criando os subplots
axs[0, 0].plot(df.index, df['CORE'])
axs[0, 0].set_title('CORE vs INPUT')
axs[0, 0].set_xlabel('INPUT')
axs[0, 0].set_ylabel('CORE')

axs[0, 1].plot(df.index, df['CPU'])
axs[0, 1].set_title('CPU vs INPUT')
axs[0, 1].set_xlabel('INPUT')
axs[0, 1].set_ylabel('CPU')

axs[0, 2].plot(df.index, df['DRAM'])
axs[0, 2].set_title('DRAM vs INPUT')
axs[0, 2].set_xlabel('INPUT')
axs[0, 2].set_ylabel('DRAM')

axs[1, 0].plot(df.index, df['DURATION'])
axs[1, 0].set_title('DURATION vs INPUT')
axs[1, 0].set_xlabel('INPUT')
axs[1, 0].set_ylabel('DURATION')

axs[1, 1].plot(df.index, df['UNCORE'])
axs[1, 1].set_title('UNCORE vs INPUT')
axs[1, 1].set_xlabel('INPUT')
axs[1, 1].set_ylabel('UNCORE')

axs[1, 2].plot(df.index, df['ENERGY'])
axs[1, 2].set_title('ENERGY vs INPUT')
axs[1, 2].set_xlabel('ENERGY')
axs[1, 2].set_ylabel('INPUT')

plt.subplots_adjust(wspace=0.3, hspace=0.3)
#axs[1, 1].remove()

# Exibindo a figura
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 1.2 - LU Decomposition

# %%
dados = pd.read_csv('/content/drive/MyDrive/TCC/DADOS/LUD.csv', sep=';')

dados = dados.drop(columns=["EXIT_CODE"])

dados = microjoule_to_joule(dados)

dados['ENERGY'] = dados['CPU'] + dados['DRAM'] + dados['UNCORE']

df = dados.groupby('INPUT').mean()
# Criando a figura e os subplots
fig, axs = plt.subplots(2, 3, figsize=(16, 8))
fig.suptitle('LU Decomposition')

# Criando os subplots
axs[0, 0].plot(df.index, df['CORE'])
axs[0, 0].set_title('CORE vs INPUT')
axs[0, 0].set_xlabel('INPUT')
axs[0, 0].set_ylabel('CORE')

axs[0, 1].plot(df.index, df['CPU'])
axs[0, 1].set_title('CPU vs INPUT')
axs[0, 1].set_xlabel('INPUT')
axs[0, 1].set_ylabel('CPU')

axs[0, 2].plot(df.index, df['DRAM'])
axs[0, 2].set_title('DRAM vs INPUT')
axs[0, 2].set_xlabel('INPUT')
axs[0, 2].set_ylabel('DRAM')

axs[1, 0].plot(df.index, df['DURATION'])
axs[1, 0].set_title('DURATION vs INPUT')
axs[1, 0].set_xlabel('INPUT')
axs[1, 0].set_ylabel('DURATION')

axs[1, 1].plot(df.index, df['UNCORE'])
axs[1, 1].set_title('UNCORE vs INPUT')
axs[1, 1].set_xlabel('INPUT')
axs[1, 1].set_ylabel('UNCORE')

axs[1, 2].plot(df.index, df['ENERGY'])
axs[1, 2].set_title('ENERGY vs INPUT')
axs[1, 2].set_xlabel('ENERGY')
axs[1, 2].set_ylabel('INPUT')

plt.subplots_adjust(wspace=0.3, hspace=0.3)
#axs[1, 1].remove()

# Exibindo a figura
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 1.3 - Back Propagation

# %%
dados = pd.read_csv('/content/drive/MyDrive/TCC/DADOS/BACKPROP.csv', sep=';')

dados = dados.drop(columns=["EXIT_CODE"])

dados = microjoule_to_joule(dados)

dados['ENERGY'] = dados['CPU'] + dados['DRAM'] + dados['UNCORE']

df = dados.groupby('INPUT').mean()
# Criando a figura e os subplots
fig, axs = plt.subplots(2, 3, figsize=(16, 8))
fig.suptitle('Back Propagation')

# Criando os subplots
axs[0, 0].plot(df.index, df['CORE'])
axs[0, 0].set_title('CORE vs INPUT')
axs[0, 0].set_xlabel('INPUT')
axs[0, 0].set_ylabel('CORE')

axs[0, 1].plot(df.index, df['CPU'])
axs[0, 1].set_title('CPU vs INPUT')
axs[0, 1].set_xlabel('INPUT')
axs[0, 1].set_ylabel('CPU')

axs[0, 2].plot(df.index, df['DRAM'])
axs[0, 2].set_title('DRAM vs INPUT')
axs[0, 2].set_xlabel('INPUT')
axs[0, 2].set_ylabel('DRAM')

axs[1, 0].plot(df.index, df['DURATION'])
axs[1, 0].set_title('DURATION vs INPUT')
axs[1, 0].set_xlabel('INPUT')
axs[1, 0].set_ylabel('DURATION')

axs[1, 1].plot(df.index, df['UNCORE'])
axs[1, 1].set_title('UNCORE vs INPUT')
axs[1, 1].set_xlabel('INPUT')
axs[1, 1].set_ylabel('UNCORE')

axs[1, 2].plot(df.index, df['ENERGY'])
axs[1, 2].set_title('ENERGY vs INPUT')
axs[1, 2].set_xlabel('ENERGY')
axs[1, 2].set_ylabel('INPUT')

plt.subplots_adjust(wspace=0.3, hspace=0.3)
#axs[1, 1].remove()

# Exibindo a figura
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 1.4 - Myocyte

# %%
dados = pd.read_csv('/content/drive/MyDrive/TCC/DADOS/MYO.csv', sep=';')

dados = dados.drop(columns=["EXIT_CODE"])

dados = microjoule_to_joule(dados)

dados['ENERGY'] = dados['CPU'] + dados['DRAM'] + dados['UNCORE']

df = dados.groupby('INPUT').mean()
# Criando a figura e os subplots
fig, axs = plt.subplots(2, 3, figsize=(16, 8))
fig.suptitle('Myocyte')

# Criando os subplots
axs[0, 0].plot(df.index, df['CORE'])
axs[0, 0].set_title('CORE vs INPUT')
axs[0, 0].set_xlabel('INPUT')
axs[0, 0].set_ylabel('CORE')

axs[0, 1].plot(df.index, df['CPU'])
axs[0, 1].set_title('CPU vs INPUT')
axs[0, 1].set_xlabel('INPUT')
axs[0, 1].set_ylabel('CPU')

axs[0, 2].plot(df.index, df['DRAM'])
axs[0, 2].set_title('DRAM vs INPUT')
axs[0, 2].set_xlabel('INPUT')
axs[0, 2].set_ylabel('DRAM')

axs[1, 0].plot(df.index, df['DURATION'])
axs[1, 0].set_title('DURATION vs INPUT')
axs[1, 0].set_xlabel('INPUT')
axs[1, 0].set_ylabel('DURATION')

axs[1, 1].plot(df.index, df['UNCORE'])
axs[1, 1].set_title('UNCORE vs INPUT')
axs[1, 1].set_xlabel('INPUT')
axs[1, 1].set_ylabel('UNCORE')

axs[1, 2].plot(df.index, df['ENERGY'])
axs[1, 2].set_title('ENERGY vs INPUT')
axs[1, 2].set_xlabel('ENERGY')
axs[1, 2].set_ylabel('INPUT')

plt.subplots_adjust(wspace=0.3, hspace=0.3)
#axs[1, 1].remove()

# Exibindo a figura
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 1.5 - Stream Cluster

# %%
dados = pd.read_csv('/content/drive/MyDrive/TCC/DADOS/STREAM.csv', sep=';')

dados = dados.drop(columns=["EXIT_CODE"])

dados = microjoule_to_joule(dados)

dados['ENERGY'] = dados['CPU'] + dados['DRAM'] + dados['UNCORE']

df = dados.groupby('INPUT').mean()
# Criando a figura e os subplots
fig, axs = plt.subplots(2, 3, figsize=(16, 8))
fig.suptitle('Stream Cluster')

# Criando os subplots
axs[0, 0].plot(df.index, df['CORE'])
axs[0, 0].set_title('CORE vs INPUT')
axs[0, 0].set_xlabel('INPUT')
axs[0, 0].set_ylabel('CORE')

axs[0, 1].plot(df.index, df['CPU'])
axs[0, 1].set_title('CPU vs INPUT')
axs[0, 1].set_xlabel('INPUT')
axs[0, 1].set_ylabel('CPU')

axs[0, 2].plot(df.index, df['DRAM'])
axs[0, 2].set_title('DRAM vs INPUT')
axs[0, 2].set_xlabel('INPUT')
axs[0, 2].set_ylabel('DRAM')

axs[1, 0].plot(df.index, df['DURATION'])
axs[1, 0].set_title('DURATION vs INPUT')
axs[1, 0].set_xlabel('INPUT')
axs[1, 0].set_ylabel('DURATION')

axs[1, 1].plot(df.index, df['UNCORE'])
axs[1, 1].set_title('UNCORE vs INPUT')
axs[1, 1].set_xlabel('INPUT')
axs[1, 1].set_ylabel('UNCORE')

axs[1, 2].plot(df.index, df['ENERGY'])
axs[1, 2].set_title('ENERGY vs INPUT')
axs[1, 2].set_xlabel('ENERGY')
axs[1, 2].set_ylabel('INPUT')

plt.subplots_adjust(wspace=0.3, hspace=0.3)
#axs[1, 1].remove()

# Exibindo a figura
plt.tight_layout()
plt.show()

# %% [markdown]
# # 2 Parte - Contribuição de cada componente para o consumo energético

# %% [markdown]
# ## Subplot completo

# %%
caminhos_csv
# Out:
# ['/content/drive/MyDrive/TCC/DADOS/STREAM.csv',
#  '/content/drive/MyDrive/TCC/DADOS/MYO.csv',
#  '/content/drive/MyDrive/TCC/DADOS/LUD.csv',
#  '/content/drive/MyDrive/TCC/DADOS/LAVAMD.csv',
#  '/content/drive/MyDrive/TCC/DADOS/BACKPROP.csv']

# %%
nomes_benchmarks
# Out:
# ['Stream Cluster',
#  'Myocyte',
#  'LU Decomposition',
#  'Lava MD',
#  'Back Propagation']

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Criação da figura e dos subplots
fig, axs = plt.subplots(2, 3, figsize=(10, 8))
fig.suptitle('Contribuição de cada componente para o consumo energético')

# Iteração sobre os arquivos CSV
for i, (caminho_csv, nome_benchmark) in enumerate(zip(caminhos_csv, nomes_benchmarks)):
    # Carregar o dataframe com os dados do benchmark
    df = pd.read_csv(caminho_csv, sep=';')
    df = microjoule_to_joule(df)
    # Calcular a soma do consumo energético por componente
    total_energy = df[['CPU', 'DRAM', 'UNCORE']].sum()

    # Calcular a porcentagem de contribuição de cada componente
    percentage_energy = (total_energy / total_energy.sum()) * 100

    # Definir as posições dos subplots
    row = i // 3
    col = i % 3

    # Plotar o gráfico de barras na posição correta
    axs[row, col].bar(percentage_energy.index, percentage_energy)
    axs[row, col].set_xlabel('Componente do sistema')
    axs[row, col].set_ylabel('Porcentagem de consumo')
    axs[row, col].set_title(f'Benchmark {nome_benchmark}')

# Ajustar espaçamento entre os subplots
plt.subplots_adjust(wspace=0.6, hspace=0.8)

# Exibir a figura
plt.show()

# %% [markdown]
# # 3 Parte - Comparações entre Benchmarks

# %% [markdown]
# ## CPU

# %%
# Criação da figura e dos subplots
fig, axs = plt.subplots(2, 3, figsize=(12, 8))
fig.suptitle('Consumo de CPU em relação aos Inputs')
# Iteração sobre os arquivos CSV
for i, (caminho_csv, nome_benchmark) in enumerate(zip(caminhos_csv, nomes_benchmarks)):
    # Carregar o dataframe com os dados do benchmark
    df = pd.read_csv(caminho_csv, sep=';')
    df = microjoule_to_joule(df)

    # Calcular a média do consumo de CPU por input
    df_mean = df.groupby('INPUT')['CPU'].mean()

    # Definir as posições dos subplots
    row = i // 3
    col = i % 3

    # Plotar o consumo de CPU em relação aos inputs
    axs[row, col].plot(df_mean.index, df_mean)
    axs[row, col].set_title(nome_benchmark)
    axs[row, col].set_xlabel('Input')
    axs[row, col].set_ylabel('Consumo de CPU (J)')

plt.subplots_adjust(wspace=0.4, hspace=0.4)

# Exibir a figura
plt.tight_layout()
plt.show()

# %% [markdown]
# ## DRAM

# %%
# Criação da figura e dos subplots
fig, axs = plt.subplots(2, 3, figsize=(12, 8))
fig.suptitle('Consumo de  DRAM em relação aos Inputs')

# Iteração sobre os arquivos CSV
for i, (caminho_csv, nome_benchmark) in enumerate(zip(caminhos_csv, nomes_benchmarks)):
    # Carregar o dataframe com os dados do benchmark
    df = pd.read_csv(caminho_csv, sep=';')
    df = microjoule_to_joule(df)
    # Calcular a média do consumo de CPU por input
    df_mean = df.groupby('INPUT')['DRAM'].mean()

    # Definir as posições dos subplots
    row = i // 3
    col = i % 3

    # Plotar o consumo de CPU em relação aos inputs
    axs[row, col].plot(df_mean.index, df_mean)
    axs[row, col].set_title(nome_benchmark)
    axs[row, col].set_xlabel('Input')
    axs[row, col].set_ylabel('Consumo de DRAM (J)')

plt.subplots_adjust(wspace=0.4, hspace=0.4)

# Exibir a figura
plt.tight_layout()
plt.show()

# %% [markdown]
# ## UNCORE

# %%
# Criação da figura e dos subplots
fig, axs = plt.subplots(2, 3, figsize=(12, 8))
fig.suptitle('Consumo de UNCORE em relação aos Inputs')

# Iteração sobre os arquivos CSV
for i, (caminho_csv, nome_benchmark) in enumerate(zip(caminhos_csv, nomes_benchmarks)):
    # Carregar o dataframe com os dados do benchmark
    df = pd.read_csv(caminho_csv, sep=';')
    df = microjoule_to_joule(df)
    # Calcular a média do consumo de CPU por input
    df_mean = df.groupby('INPUT')['UNCORE'].mean()

    # Definir as posições dos subplots
    row = i // 3
    col = i % 3

    # Plotar o consumo de CPU em relação aos inputs
    axs[row, col].plot(df_mean.index, df_mean)
    axs[row, col].set_title(nome_benchmark)
    axs[row, col].set_xlabel('Input')
    axs[row, col].set_ylabel('Consumo de UNCORE (J)')

plt.subplots_adjust(wspace=0.4, hspace=0.4)

# Exibir a figura
plt.tight_layout()
plt.show()

# %% [markdown]
# ## DURATION

# %%
# Criação da figura e dos subplots
fig, axs = plt.subplots(2, 3, figsize=(12, 8))
fig.suptitle('Duração em relação aos Inputs')

# Iteração sobre os arquivos CSV
for i, (caminho_csv, nome_benchmark) in enumerate(zip(caminhos_csv, nomes_benchmarks)):
    # Carregar o dataframe com os dados do benchmark
    df = pd.read_csv(caminho_csv, sep=';')

    df = microjoule_to_joule(df)
    # Calcular a média do consumo de CPU por input
    df_mean = df.groupby('INPUT')['DURATION'].mean()

    # Definir as posições dos subplots
    row = i // 3
    col = i % 3

    # Plotar o consumo de CPU em relação aos inputs
    axs[row, col].plot(df_mean.index, df_mean)
    axs[row, col].set_title(nome_benchmark)
    axs[row, col].set_xlabel('Input')
    axs[row, col].set_ylabel('Tempo de execucao(S)')

plt.subplots_adjust(wspace=0.4, hspace=0.4)

# Exibir a figura
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Consumo Total

# %%
# Criação da figura e dos subplots
fig, axs = plt.subplots(2, 3, figsize=(12, 8))
fig.suptitle('Consumo Total em relação aos Inputs')

# Iteração sobre os arquivos CSV
for i, (caminho_csv, nome_benchmark) in enumerate(zip(caminhos_csv, nomes_benchmarks)):
    # Carregar o dataframe com os dados do benchmark
    df = pd.read_csv(caminho_csv, sep=';')

    df['ENERGY'] = df['CPU'] + df['DRAM'] + df['UNCORE']

    df_mean = df.groupby('INPUT')['ENERGY'].mean()

 # Definir as posições dos subplots
    row = i // 3
    col = i % 3

    # Plotar o consumo de CPU em relação aos inputs
    axs[row, col].plot(df_mean.index, df_mean)
    axs[row, col].set_title(nome_benchmark)
    axs[row, col].set_xlabel('Input')
    axs[row, col].set_ylabel('Consumo de ENERGY')

plt.subplots_adjust(wspace=0.4, hspace=0.4)

# Exibir a figura
plt.tight_layout()
plt.show()

# %% [markdown]
# TESTE

# %% [markdown]
# # Teste -  Scikit-learn Regressão

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression

# %% [markdown]
# CPU e DRAM - Regressão Linear

# %%
# caminhos_csv = ['/content/drive/MyDrive/TCC/DADOS/STREAM.csv',
#                 '/content/drive/MyDrive/TCC/DADOS/MYO.csv',
#                 '/content/drive/MyDrive/TCC/DADOS/LUD.csv',
#                 '/content/drive/MyDrive/TCC/DADOS/LAVAMD.csv',
#                 '/content/drive/MyDrive/TCC/DADOS/BACKPROP.csv']

df = pd.read_csv('/content/drive/MyDrive/TCC/DADOS/LUD.csv', sep=';')
# df = pd.read_csv('/content/drive/MyDrive/TCC/DADOS/MYO.csv, sep=';')
# df = pd.read_csv('/content/drive/MyDrive/TCC/DADOS/LUD.csv', sep=';')
# df = pd.read_csv('/content/drive/MyDrive/TCC/DADOS/BACKPROP.csv', sep=';')
df = microjoule_to_joule(df)
df.head()
# Out:
#      CORE     CPU    DRAM  DURATION  UNCORE  EXIT_CODE  INPUT
# 0  480.70  566.18   89.54     35.81    0.03          0  10240
# 1  468.04  550.81   90.90     34.40    0.02          0  10560
# 2  469.27  558.97   98.50     37.39    0.03          0  10880
# 3  497.05  599.64  110.48     42.90    0.02          0  11200
# 4  518.06  623.15  114.75     43.83    0.04          0  11520

# %%
X_train = df[['INPUT']][:90]
y_train_cpu = df['CPU'][:90]
y_train_dram = df['DRAM'][:90]

regression_cpu = LinearRegression()
regression_dram = LinearRegression()

regression_cpu.fit(X_train, y_train_cpu)
regression_dram.fit(X_train, y_train_dram)

X_inputs = df[['INPUT']][-10:]

y_pred_cpu = regression_cpu.predict(X_inputs)
y_pred_dram = regression_dram.predict(X_inputs)

print(y_pred_cpu)
print(y_pred_dram)
# Out:
# [15679.554727   15886.81097156 16094.06721612 16301.32346067
#  16508.57970523 16715.83594979 16923.09219434 17130.3484389
#  17337.60468346 17544.86092802]
# [4166.11387935 4222.97629743 4279.83871551 4336.70113358 4393.56355166
#  4450.42596974 4507.28838781 4564.15080589 4621.01322396 4677.87564204]

# %%
plt.scatter(X_inputs.index, y_pred_cpu, color='red', label='Previsto')
plt.scatter(X_train.index, y_train_cpu, color='blue', label='Real')
plt.xlabel('Índice')
plt.ylabel('Consumo de CPU')
plt.title('Previsão de Consumo de CPU')
plt.legend()
plt.show()

# Plot para consumo de DRAM
plt.scatter(X_inputs.index, y_pred_dram, color='red', label='Previsto')
plt.scatter(X_train.index, y_train_dram, color='blue', label='Real')
plt.xlabel('Índice')
plt.ylabel('Consumo de DRAM')
plt.title('Previsão de Consumo de DRAM')
plt.legend()
plt.show()

# %% [markdown]
# CPU e DRAM - Regressão Polinomial

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

# %%
df = pd.read_csv('/content/drive/MyDrive/TCC/DADOS/STREAM.csv', sep=';')
df = microjoule_to_joule(df)
df['ENERGY'] = df['CPU'] + df['DRAM'] + df['UNCORE']

X_train = df[['INPUT']][:50]
y_train_ENERGY = df['ENERGY'][:50]

#o grau do polinômio
grau = 1
poly_features = PolynomialFeatures(degree=grau)
X_train_poly = poly_features.fit_transform(X_train)

regression_ENERGY = LinearRegression()
regression_ENERGY.fit(X_train_poly, y_train_ENERGY)

X_inputs = df[['INPUT']][-10:]
X_inputs_poly = poly_features.transform(X_inputs)

y_pred_ENERGY = regression_ENERGY.predict(X_inputs_poly)

print(y_pred_ENERGY)
# Out:
# [20511.9687563  20719.50923986 20927.04972341 21134.59020696
#  21342.13069052 21549.67117407 21757.21165762 21964.75214118
#  22172.29262473 22379.83310828]

# %%
plt.scatter(X_inputs['INPUT'], y_pred_ENERGY, color='red', label='Previsto')
##plt.scatter(X_train['INPUT'], y_train_ENERGY, color='blue', label='Real')
plt.scatter(df['INPUT'], df['ENERGY'], color='blue', label='Real')
plt.xlabel('Índice')
plt.ylabel('Consumo ')
plt.title('Previsão de Consumo ')
plt.legend()
plt.show()

# %% [markdown]
# # Regressão Polinomial

# %%
#Criação das Figuras

fig, axs = plt.subplots(2, 3, figsize=(12, 8))
fig.suptitle('Consumo Total em relação aos Inputs')

for i, (caminho_csv, nome_benchmark) in enumerate(zip(caminhos_csv, nomes_benchmarks)):
    # Carregar o dataframe com os dados do benchmark
    df = pd.read_csv(caminho_csv, sep=';')
    df = microjoule_to_joule(df)
    df['ENERGY'] = df['CPU'] + df['DRAM'] + df['UNCORE']

    X_train = df[['INPUT']][:80]
    y_train_ENERGY = df['ENERGY'][:80]

    #o grau do polinômio
    grau = 3
    poly_features = PolynomialFeatures(degree=grau)
    X_train_poly = poly_features.fit_transform(X_train)

    regression_ENERGY = LinearRegression()
    regression_ENERGY.fit(X_train_poly, y_train_ENERGY)

    X_inputs = df[['INPUT']][-10:]
    X_inputs_poly = poly_features.transform(X_inputs)
    y_pred_ENERGY = regression_ENERGY.predict(X_inputs_poly)

    # Definir as posições dos subplots
    row = i // 3
    col = i % 3

    # Plotar o gráfico de previsão do consumo de energia
    axs[row, col].scatter(X_inputs['INPUT'], y_pred_ENERGY, color='red', label='Previsto')
    axs[row, col].scatter(df['INPUT'], df['ENERGY'], color='blue', label='Real')
    axs[row, col].set_title(nome_benchmark)
    axs[row, col].set_xlabel('INPUT')
    axs[row, col].set_ylabel('ENERGY (J)')
    axs[row, col].legend()

plt.subplots_adjust(wspace=0.4, hspace=0.4)

plt.tight_layout()
plt.show()
